# %%
import os
import pandas as pd
import numpy as np

from sodapy import Socrata

# %%
socrata_domain = 'chronicdata.cdc.gov'
socrata_dataset_identifier = '6ay3-nik2'
socrata_token = 'EIpPyO8RsB6PuFaA9MmD84XIk'

# %%
client = Socrata(socrata_domain, socrata_token)
print("Domain: {domain:}\nSession: {session:}\nURI Prefix: {uri_prefix:}".format(**client.__dict__))
# Out:
# Domain: chronicdata.cdc.gov
# Session: <requests.sessions.Session object at 0x7f753f8f6358>
# URI Prefix: https://

# %%
results = client.get(socrata_dataset_identifier)
df = pd.DataFrame.from_dict(results)
df.head()
# Out:
#   :@computed_region_bxsw_vy29 :@computed_region_he4y_prf8 data_value_symbol  \
# 0                          30                        1078                 %
# 1                         NaN                         NaN                 %
# 2                          47                        2137                 %
# 3                          27                        2658                 %
# 4                          23                        2024                 %
#
#   data_value_type datasource  \
# 0      Percentage      YRBSS
# 1      Percentage      YRBSS
# 2      Percentage      YRBSS
# 3      Percentage      YRBSS
# 4      Percentage      YRBSS
#
#                                          description  \
# 0  on at least 1 day during the 30 days before th...
# 1                                               NULL
# 2                    also called grass, pot, or weed
# 3                                               NULL
# 4             during the 12 months before the survey
#
# ...

# %%
query = """
select 
    *
where
    shortquestiontext == 'Initiation of marijuana use'
    and grade == '12th'
"""
results = client.get(socrata_dataset_identifier, query=query)
len(results)
# Out:
# 1000

# %%
results = client.get(socrata_dataset_identifier, query="select DISTINCT locationdesc where locationdesc is not null")
results
# Out:
# [{'locationdesc': 'Alabama'},
#  {'locationdesc': 'Alaska'},
#  {'locationdesc': 'American Samoa'},
#  {'locationdesc': 'Arizona'},
#  {'locationdesc': 'Arkansas'},
#  {'locationdesc': 'Baltimore, MD'},
#  {'locationdesc': 'Borough of Bronx, NY'},
#  {'locationdesc': 'Borough of Brooklyn, NY'},
#  {'locationdesc': 'Borough of Manhattan, NY'},
#  {'locationdesc': 'Borough of Queens, NY'},
#  {'locationdesc': 'Borough of Staten Island, NY'},
#  {'locationdesc': 'Boston, MA'},
#  {'locationdesc': 'Broward County, FL'},
#  {'locationdesc': 'California'},
#  {'locationdesc': 'Charlotte-Mecklenburg County, NC'},
#  {'locationdesc': 'Chicago, IL'},
#  {'locationdesc': 'Cleveland, OH'},
#  {'locationdesc': 'Colorado'},
#  {'locationdesc': 'Connecticut'},
#  {'locationdesc': 'Dallas, TX'},
#  {'locationdesc': 'DeKalb County, GA'},
#  {'locationdesc': 'Delaware'},
#  {'locationdesc': 'Denver, CO'},
#  {'locationdesc': 'Detroit, MI'},
#  {'locationdesc': 'District of Columbia'},
# ...
